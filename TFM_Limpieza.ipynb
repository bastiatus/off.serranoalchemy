# %% [markdown]
# <a href="https://colab.research.google.com/github/bastiatus/off.serranoalchemy/blob/main/TFM_Limpieza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Trabajo Final del Master

# %% [markdown]
# ##Limpieza

# %% [markdown]
# Diccionario https://world.openfoodfacts.org/data/data-fields.txt

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/bastiatus/off.serranoalchemy/main/off.onlyserrano.json"
df = pd.read_json(url, dtype={'code': str})
pd.set_option('display.float_format', '{:.2f}'.format)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Expandimos "nutriments"

# %%
df_expanded_nutriments = pd.json_normalize(df['nutriments'])
#df_expanded_source = pd.json_normalize(df['sources'])

#df = pd.concat([df.drop(['nutriments', 'sources'], axis=1), df_expanded_nutriments, df_expanded_source], axis=1)
df = pd.concat([df.drop(['nutriments'], axis=1), df_expanded_nutriments], axis=1)

# %% [markdown]
# Listado de columnas de "nutriments"

# %%
column_names = df_expanded_nutriments.columns.tolist()
column_names.sort()

# Mostrar los nombres de columna ordenados
column_names
# Out:
# ['alcohol',
#  'alcohol_100g',
#  'alcohol_serving',
#  'alcohol_unit',
#  'alcohol_value',
#  'calcium',
#  'calcium_100g',
#  'calcium_serving',
#  'calcium_unit',
#  'calcium_value',
#  'carbohydrates',
#  'carbohydrates_100g',
#  'carbohydrates_modifier',
#  'carbohydrates_serving',
#  'carbohydrates_unit',
#  'carbohydrates_value',
#  'carbon-footprint-from-known-ingredients_100g',
#  'carbon-footprint-from-known-ingredients_product',
#  'carbon-footprint-from-known-ingredients_serving',
#  'carbon-footprint-from-meat-or-fish_100g',
#  'carbon-footprint-from-meat-or-fish_product',
#  'carbon-footprint-from-meat-or-fish_serving',
#  'cholesterol',
#  'cholesterol_100g',
#  'cholesterol_serving',
#  'cholesterol_unit',
#  'cholesterol_value',
#  'energy',
#  'energy-kcal',
#  'energy-kcal_100g',
#  'energy-kcal_serving',
#  'energy-kcal_unit',
#  'energy-kcal_value',
#  'energy-kcal_value_computed',
#  'energy-kj',
#  'energy-kj_100g',
#  'energy-kj_serving',
#  'energy-kj_unit',
#  'energy-kj_value',
#  'energy-kj_value_computed',
#  'energy_100g',
#  'energy_serving',
#  'energy_unit',
#  'energy_value',
#  'fat',
#  'fat_100g',
#  'fat_serving',
#  'fat_unit',
#  'fat_value',
#  'fiber',
#  'fiber_100g',
#  'fiber_modifier',
#  'fiber_serving',
#  'fiber_unit',
#  'fiber_value',
#  'fruits-vegetables-nuts',
#  'fruits-vegetables-nuts-estimate-from-ingredients_100g',
#  'fruits-vegetables-nuts-estimate-from-ingredients_serving',
#  'fruits-vegetables-nuts_100g',
#  'fruits-vegetables-nuts_serving',
#  'fruits-vegetables-nuts_unit',
#  'fruits-vegetables-nuts_value',
#  'iron',
#  'iron_100g',
#  'iron_serving',
#  'iron_unit',
#  'iron_value',
#  'nova-group',
#  'nova-group_100g',
#  'nova-group_serving',
#  'nutrition-score-fr',
#  'nutrition-score-fr_100g',
#  'phosphorus',
#  'phosphorus_100g',
#  'phosphorus_label',
#  'phosphorus_unit',
#  'phosphorus_value',
#  'potassium',
#  'potassium_100g',
#  'potassium_label',
#  'potassium_unit',
#  'potassium_value',
#  'proteins',
#  'proteins_100g',
#  'proteins_modifier',
#  'proteins_serving',
#  'proteins_unit',
#  'proteins_value',
#  'salt',
#  'salt_100g',
#  'salt_serving',
#  'salt_unit',
#  'salt_value',
#  'saturated-fat',
#  'saturated-fat_100g',
#  'saturated-fat_serving',
#  'saturated-fat_unit',
#  'saturated-fat_value',
#  'sodium',
#  'sodium_100g',
#  'sodium_serving',
#  'sodium_unit',
#  'sodium_value',
#  'sugars',
#  'sugars_100g',
#  'sugars_modifier',
#  'sugars_serving',
#  'sugars_unit',
#  'sugars_value',
#  'till-100-g-färdig-produkt-har-x-g-kött-använts',
#  'till-100-g-färdig-produkt-har-x-g-kött-använts_100g',
#  'till-100-g-färdig-produkt-har-x-g-kött-använts_label',
#  'till-100-g-färdig-produkt-har-x-g-kött-använts_unit',
#  'till-100-g-färdig-produkt-har-x-g-kött-använts_value',
#  'trans-fat',
#  'trans-fat_100g',
#  'trans-fat_serving',
#  'trans-fat_unit',
#  'trans-fat_value',
#  'vitamin-a',
#  'vitamin-a_100g',
#  'vitamin-a_serving',
#  'vitamin-a_unit',
#  'vitamin-a_value',
#  'vitamin-c',
#  'vitamin-c_100g',
#  'vitamin-c_serving',
#  'vitamin-c_unit',
#  'vitamin-c_value',
#  'zinc',
#  'zinc_100g',
#  'zinc_label',
#  'zinc_unit',
#  'zinc_value']

# %% [markdown]
# Agregamos las columnas que necesitamos ("Ver Diccionario").

# %%
#ver diccionario
columnas_interes = ['code',
                    'product_name',
                    'quantity',
                    'categories',
                    'countries',
                    'ingredients_text',
                    'nutrition_grade_fr',
                    'additives_n',
                    'additives_tags',
                    'energy_100g',
                    'sodium_value',
                    'sugars',
                    'salt_value',
                    'saturated-fat',
                    'carbohydrates',
                    'fat_value',
                    'cholesterol_value',
                    'proteins_value',
                    'fiber',
                    'fruits-vegetables-nuts_100g_estimate',
                    'ingredients_original_tags'
                    ]

df_col = df[columnas_interes]
df_col.head(10)
# Out:
#             code  \
# 0  0017869707759
# 1  0017869727771
# 2  0017869777721
# 3  0736436501421
# 4  0736436509052
# 5  0736436521405
# 6       20027487
# 7       20041083
# 8       20087487
# 9       20296070
#
#                                                                 product_name  \
# 0  Jamon serrano dry cured ham coated with paprika slices separated by paper
# 1                                                              Jamon Serrano
# 2                                 Naturalissima, Jamon Serrano Dry Cured Ham
# 3                                                    Del Duca, Jamon Serrano
# 4                                                     Del Duca Jamon Serrano
# 5                                                     Del Duca Jamon Serrano
# 6                                                  jamon serrano. ham slices
# 7                                                              Jamón Serrano
# 8                                                  Spanish Ham Jamón Serrano
# 9                                                      Jamón Serrano Reserva
#
#   quantity  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6    100 g
# 7      NaN
# 8     100g
# 9    240 g
#
#                                                                                                                                                                       categories  \
# 0                                                     Meats, Prepared meats, Meat-based-products, Hams, Cured ham, Dried hams, Spanish meat products, Serrano ham, Raw-cured-ham
# 1                                                     Meats, Prepared meats, Meat-based-products, Hams, Cured ham, Dried hams, Spanish meat products, Serrano ham, Raw-cured-ham
# 2                                                     Meats, Prepared meats, Meat-based-products, Hams, Cured ham, Dried hams, Spanish meat products, Serrano ham, Raw-cured-ham
# 3                                                     Meats, Prepared meats, Meat-based-products, Hams, Cured ham, Dried hams, Spanish meat products, Serrano ham, Raw-cured-ham
# 4                                                     Meats, Prepared meats, Meat-based-products, Hams, Cured ham, Dried hams, Spanish meat products, Serrano ham, Raw-cured-ham
# 5                                                     Meats, Prepared meats, Meat-based-products, Hams, Cured ham, Dried hams, Spanish meat products, Serrano ham, Raw-cured-ham
# 6                                                     Meats, Prepared meats, Meat-based-products, Hams, Cured ham, Dried hams, Spanish meat products, Serrano ham, Raw-cured-ham
# 7                               Viandes, Charcuteries, en:meat-based-products, Jambons, Jambons crus, Jambons secs, Produits carnés espagnols, Jambons Serrano, en:raw-cured-ham
# 8  Auf Fleisch basierende Lebensmittel,Fleisch,Zubereitetes Fleisch,Schinken,Unbehandelte Schinken,Getrockene Schinken,Spanische Fleischprodukte,en:Serrano ham,en:Raw-cured-ham
# 9                  Produtos à base de carne,Carnes,Carnes preparadas,Presuntos,en:Cured ham,Presuntos secos,en:Spanish meat products,en:Serrano ham,en:raw-cured-ham,Cured meats
#
#                         countries  \
# 0                   United States
# 1                   United States
# 2                   United States
# 3                   United States
# 4                   United States
# 5                   United States
# 6                  United Kingdom
# 7              France, en:belgium
# 8  Frankreich,Deutschland,Schweiz
# 9                        Portugal
#
#                                                                                       ingredients_text  \
# 0                                                                                 Pork, salt, paprika.
# 1                                                       Pork, salt, potassium nitrate, sodium nitrite.
# 2                                                                              Pork sea salt, paprika.
# 3                                                                                            Pork salt
# 4                                                                                          Pork, salt.
# 5                                                                                          Pork, salt.
# 6                                                                                                  NaN
# 7                                                                                                  NaN
# 8  pork, salt, sugar, preservatives: sodium nitrite, potassium nitrate, antioxidant: sodium ascorbate,
# 9
#
#   nutrition_grade_fr  additives_n               additives_tags  energy_100g  \
# 0                  e         0.00                           []      1197.00
# 1                  d         1.00                    [en:e250]       895.00
# 2                  e         0.00                           []      1197.00
# 3                NaN         0.00                           []       895.00
# 4                NaN         0.00                           []       895.00
# 5                NaN         0.00                           []       895.00
# 6                NaN          NaN                           []          NaN
# 7                  d          NaN                           []       983.00
# 8                  d         3.00  [en:e250, en:e252, en:e301]       971.00
# 9                  d          NaN                           []       983.00
#
#    sodium_value  sugars  salt_value  saturated-fat  carbohydrates  fat_value  \
# 0       2286.00    0.00     5715.00          12.50           0.00      21.43
# 1          1.29    0.00        3.21           3.57           0.00       8.93
# 2       2286.00    0.00     5715.00          12.50           0.00      21.43
# 3          2.36     NaN        5.90           3.57           3.57      10.71
# 4       2321.00     NaN     5802.50           3.57           3.57      10.71
# 5       2321.00     NaN     5802.50           3.57           3.57      10.71
# 6           NaN     NaN         NaN            NaN            NaN        NaN
# 7          1.52    0.30        3.80           4.20           0.30      12.90
# 8          2.00    1.00        5.00           4.50           1.00      12.00
# 9          1.52    0.00        3.80           4.20           0.30      12.90
#
#    cholesterol_value  proteins_value  fiber  \
# 0              89.00           25.00   0.00
# 1              89.00           32.14   0.00
# 2              89.00           25.00   0.00
# 3              89.00           28.57    NaN
# 4              89.00           28.57    NaN
# 5              89.00           28.57    NaN
# 6                NaN             NaN    NaN
# 7                NaN           29.50    NaN
# 8                NaN           30.00   0.00
# 9                NaN           29.50    NaN
#
#    fruits-vegetables-nuts_100g_estimate  \
# 0                                  0.00
# 1                                  0.00
# 2                                  0.00
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                  0.00
# 9                                   NaN
#
#                                                                                            ingredients_original_tags
# 0                                                                                     [en:pork, en:salt, en:paprika]
# 1                                                                               [en:pork, en:salt, en:e252, en:e250]
# 2                                                                                     [en:pork-sea-salt, en:paprika]
# 3                                                                                                     [en:pork-salt]
# 4                                                                                                 [en:pork, en:salt]
# 5                                                                                                 [en:pork, en:salt]
# 6                                                                                                                NaN
# 7                                                                                                                NaN
# 8                           [en:pork, en:salt, en:sugar, en:preservative, en:e252, en:antioxidant, en:e250, en:e301]
# 9  [es:presunto-suino, en:salt, en:preservative, en:e251, en:antioxidant, es:porco, es:nitrito-de-potassio, en:e301]
